# %% [markdown]
# # **Assignment 4**

# %% [markdown]
# -Authors : Esihle Mlaka (222242769) and Bomikazi Tshalilanga(223230151)
# -Date : 14 April 2023
# -Sources:-MacroTrends_Data_Apple.xlsx
#          -MacroTrends_Data_Microsoft.xlsx
#          -MacroTrends_Data_Sasol.xlsx'

# %%
import pandas as pd
import numpy as np
from scipy.stats import skew
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.stats import kurtosis
from scipy.stats import skew
import datetime as dt
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
import ta

# %%
aapl = pd.read_excel(r'/home/f5384478/Documents/personal/Assigment 4/MacroTrends_Data_Apple.xlsx')
print(aapl)
# Out:
#            date      open      high       low     close     volume
# 0    2018-01-02   40.3879   40.8958   40.1743   40.8863  102223736
# 1    2018-01-03   40.9504   41.4299   40.8151   40.8792  118071596
# 2    2018-01-04   40.9528   41.1735   40.8436   41.0691   89738388
# 3    2018-01-05   41.1664   41.6245   41.0738   41.5367   94640072
# 4    2018-01-08   41.3824   41.6815   41.2827   41.3824   82271064
# ...         ...       ...       ...       ...       ...        ...
# 1340 2023-05-01  169.2800  170.4500  168.6400  169.5900   49391604
# 1341 2023-05-02  170.0900  170.3500  167.5400  168.5400   47986184
# 1342 2023-05-03  169.5000  170.9200  167.1600  167.4500   59438769
# 1343 2023-05-04  164.8900  167.0400  164.3100  165.7900   70216187
# 1344 2023-05-05  170.9750  174.3000  170.7600  173.5700  110756599
#
# [1345 rows x 6 columns]

# %%
msft = pd.read_excel(r'/home/f5384478/Documents/personal/Assigment 4/MacroTrends_Data_Microsoft.xlsx')
print(msft)
# Out:
#            date      open      high       low     close    volume
# 0    2018-01-02   81.1606   81.3349   80.5716   80.9957  22483797
# 1    2018-01-03   81.0946   81.5234   81.0145   81.3726  26061439
# 2    2018-01-04   81.5988   82.6071   81.5799   82.0888  21911974
# 3    2018-01-05   82.6071   83.3139   82.3903   83.1065  23407110
# 4    2018-01-08   83.1160   83.4741   82.5549   83.1913  22113049
# ...         ...       ...       ...       ...       ...       ...
# 1340 2023-05-01  306.9700  308.6000  305.1500  305.5600  21252788
# 1341 2023-05-02  307.7600  309.1800  303.9100  305.4100  26320444
# 1342 2023-05-03  306.6200  308.6100  304.0900  304.4000  22157529
# 1343 2023-05-04  306.2400  307.7626  303.4000  305.4100  22198119
# 1344 2023-05-05  305.7200  311.9700  304.2700  310.6500  27360645
#
# [1345 rows x 6 columns]

# %%
ssl = pd.read_excel(r'/home/f5384478/Documents/personal/Assigment 4/MacroTrends_Data_Sasol.xlsx')
print(ssl)
# Out:
#            date     open     high      low    close  volume
# 0    2018-01-02  30.4805  30.6007  30.3734  30.5698  225415
# 1    2018-01-03  30.5341  30.8376  30.4894  30.7841  169394
# 2    2018-01-04  30.4270  30.8823  30.4270  30.8019  126648
# 3    2018-01-05  30.9448  31.0698  30.8109  30.9805  173940
# 4    2018-01-08  31.0341  31.2216  30.9805  31.0519  149534
# ...         ...      ...      ...      ...      ...     ...
# 1340 2023-05-01  13.0100  13.0700  12.8800  12.9400  111966
# 1341 2023-05-02  12.6600  12.6600  12.2900  12.4700  290968
# 1342 2023-05-03  12.4200  12.5000  12.2800  12.2800  295698
# 1343 2023-05-04  12.2400  12.3500  12.0300  12.0400  270116
# 1344 2023-05-05  12.4100  12.6800  12.4100  12.6300  270684
#
# [1345 rows x 6 columns]

# %%
#Size and Shape
print(aapl.size)
print(aapl.shape)
# Out:
# 8070
# (1345, 6)

# %%
#Size and Shape
print(msft.size)
print(msft.shape)
# Out:
# 8070
# (1345, 6)

# %%
#Size and Shape
print(ssl.size)
print(ssl.shape)
# Out:
# 8070
# (1345, 6)

# %% [markdown]
# ## *The Stock Markets*

# %% [markdown]
# ### *1. Apple Inc*

# %%
#Clean Data
aapl.drop(aapl.columns[0]axis = 1, inplace =True)
aapl.head(10)
# Out:
#       open     high      low    close     volume
# 0  40.3879  40.8958  40.1743  40.8863  102223736
# 1  40.9504  41.4299  40.8151  40.8792  118071596
# 2  40.9528  41.1735  40.8436  41.0691   89738388
# 3  41.1664  41.6245  41.0738  41.5367   94640072
# 4  41.3824  41.6815  41.2827  41.3824   82271064
# 5  41.4299  41.5509  41.1593  41.3777   86335988
# 6  41.1000  41.3705  41.0620  41.3682   95839580
# 7  41.4394  41.6527  41.4156  41.6031   74670916
# 8  41.8168  42.0968  41.6910  42.0327  101672320
# 9  42.2250  42.5787  41.8073  41.8191  118263788

# %% [markdown]
# ### *2. Microsoft Corp*

# %%
#Clean Data
msft.drop(msft.columns[0],axis = 1, inplace =True)
msft.head(10)
# Out:
#       open     high      low    close    volume
# 0  81.1606  81.3349  80.5716  80.9957  22483797
# 1  81.0946  81.5234  81.0145  81.3726  26061439
# 2  81.5988  82.6071  81.5799  82.0888  21911974
# 3  82.6071  83.3139  82.3903  83.1065  23407110
# 4  83.1160  83.4741  82.5549  83.1913  22113049
# 5  83.5400  83.6128  82.7956  83.1348  19484317
# 6  82.7956  83.1065  82.3715  82.7579  18652201
# 7  83.0500  83.0500  82.2113  83.0029  17808877
# 8  83.5589  84.6049  83.3515  84.4353  24271531
# 9  84.9064  85.5567  82.9373  83.2573  36599736

# %% [markdown]
# ### *3. Sasol Ltd*

# %%
#Clean Data
ssl.drop(ssl.columns[0],axis = 1, inplace =True)
ssl.head(10)
# Out:
#       open     high      low    close  volume
# 0  30.4805  30.6007  30.3734  30.5698  225415
# 1  30.5341  30.8376  30.4894  30.7841  169394
# 2  30.4270  30.8823  30.4270  30.8019  126648
# 3  30.9448  31.0698  30.8109  30.9805  173940
# 4  31.0341  31.2216  30.9805  31.0519  149534
# 5  31.1144  31.2216  30.7484  30.9359  137378
# 6  31.6501  31.8644  31.4180  31.5340  277207
# 7  31.3287  31.6055  31.3287  31.5608  194382
# 8  31.9894  32.3286  31.8822  32.3197  239652
# 9  32.7661  32.9268  32.4179  32.4715  424713

# %% [markdown]
# ### *The Descriptive Statistics For All The Stock Markets*

# %% [markdown]
# - Count
# - Mean
# - Standard Deviation
# - Min
# - Max
# - 1st Quartile
# - 2nd Quartile
# - 3rd Quartile

# %%
aapl.describe().round(2)
# Out:
#           open     high      low    close        volume
# count  1345.00  1345.00  1345.00  1345.00  1.345000e+03
# mean    100.15   101.37    99.01   100.24  1.130925e+08
# std      47.17    47.77    46.60    47.22  5.494421e+07
# min      34.69    35.11    34.21    34.26  3.511605e+07
# 25%      49.98    50.47    49.57    50.14  7.616541e+07
# 50%     112.23   113.63   110.51   111.46  9.808525e+07
# 75%     144.86   146.68   143.52   145.08  1.336977e+08
# max     181.30   181.61   177.82   180.68  4.268849e+08

# %%
msft.describe().round(2)
# Out:
#           open     high      low    close        volume
# count  1345.00  1345.00  1345.00  1345.00  1.345000e+03
# mean    194.51   196.58   192.36   194.58  3.012025e+07
# std      75.26    76.06    74.43    75.29  1.269529e+07
# min      81.09    81.33    79.00    80.11  8.989150e+06
# 25%     120.74   121.53   119.60   120.84  2.217578e+07
# 50%     204.79   206.98   202.31   205.01  2.689724e+07
# 75%     256.75   259.56   253.39   256.91  3.411426e+07
# max     340.52   345.51   338.13   339.03  1.112421e+08

# %%
ssl.describe().round(2)
# Out:
#           open     high      low    close       volume
# count  1345.00  1345.00  1345.00  1345.00      1345.00
# mean     18.99    19.18    18.76    18.96    702600.73
# std       8.63     8.66     8.60     8.62   1337424.34
# min       1.35     1.35     1.16     1.24     72147.00
# 25%      13.83    13.96    13.63    13.81    199908.00
# 50%      17.16    17.32    17.00    17.16    287154.00
# 75%      26.60    26.87    26.07    26.46    535759.00
# max      36.11    36.32    35.71    35.94  18395260.00

# %% [markdown]
# #### The range for all stock markets

# %%
selected_columns = ['open','high','low','close','volume']
selected_data = aapl[selected_columns]

range_ = selected_data.max() - selected_data.min()
print('The range for Apple Inc is:\n',range_)
# Out:
# The range for Apple Inc is:
#  open      1.466133e+02
# high      1.465019e+02
# low       1.436058e+02
# close     1.464291e+02
# volume    3.917689e+08
# dtype: float64

# %%
selected_columns = ['open','high','low','close','volume']
selected_data = msft[selected_columns]

range_ = selected_data.max() - selected_data.min()
print('The range for Microsoft Corp is:\n',range_)
# Out:
# The range for Microsoft Corp is:
#  open      2.594276e+02
# high      2.641773e+02
# low       2.591331e+02
# close     2.589204e+02
# volume    1.022529e+08
# dtype: float64

# %%
selected_columns = ['open','high','low','close','volume']
selected_data = ssl[selected_columns]

range_ = selected_data.max() - selected_data.min()
print('The range for Sasol Ltd is:\n',range_)
# Out:
# The range for Sasol Ltd is:
#  open      3.476720e+01
# high      3.497800e+01
# low       3.454970e+01
# close     3.469520e+01
# volume    1.832311e+07
# dtype: float64

# %%
#### The Mode for all stock markets

# %% [markdown]
# *Apple Inc*

# %%
df_mode =aapl[['high']].mode().transpose()
df_mode = df_mode.reset_index(drop=True)
df_mode.drop(df_mode.columns[0],axis = 1, inplace=True)
display('Mode for high:',df_mode)

df_Lmode =aapl[['low']].mode().transpose()
df_Lmode = df_Lmode.reset_index(drop=True)
df_Lmode.drop(df_Lmode.columns[0],axis = 1, inplace=True)
display('Mode for open:',df_Lmode)

df_modeC =aapl[['close']].mode().transpose()
df_modeC = df_modeC.reset_index(drop=True)
df_modeC.drop(df_modeC.columns[0],axis = 1, inplace=True)
display('Mode for close:',df_modeC)

df_modeV =aapl[['volume']].mode().transpose()
df_modeV = df_modeV.reset_index(drop=True)
df_modeV.drop(df_modeV.columns[0],axis = 1, inplace=True)
display('Mode for volume:',df_modeV)
# Out:
# 'Mode for high:'
#         1        2        3        4        5        6         7         8   \
# 0  41.2488  53.1184  53.2601  53.8746  65.5378  79.4953  114.2526  114.7943
#
#          9         10        11        12
# 0  133.3957  133.9194  142.3718  142.6453
# 'Mode for open:'
#         1        2        3       4        5        6        7        8   \
# 0  41.1463  44.6836  47.0235  51.642  52.1605  53.3552  54.4076  108.343
#
#          9         10        11        12        13
# 0  115.2491  124.6536  127.9314  129.6925  146.5106
# 'Mode for close:'
#         1        2        3        4         5         6         7         8   \
# 0  41.9767  45.0113  54.4652  89.4912  120.1527  125.5543  139.8789  141.0137
#
#          9         10      11      12      13        14       15       16
# 0  144.1524  148.0316  159.28  163.76  165.23  167.8641  170.936  173.805
# 'Mode for volume:'
#        1         2         3         4         5         6         7     \
# ...

# %% [markdown]
# *Microsoft Corp*

# %%
df_mode =msft[['high']].mode().transpose()
df_mode = df_mode.reset_index(drop=True)
df_mode.drop(df_mode.columns[0],axis = 1, inplace=True)
display('Mode for high:',df_mode)

df_Lmode =msft[['low']].mode().transpose()
df_Lmode = df_Lmode.reset_index(drop=True)
df_mode.drop(df_mode.columns[0],axis = 1, inplace=True)
display('Mode for open:',df_Lmode)

df_modeC =msft[['close']].mode().transpose()
df_modeC = df_modeC.reset_index(drop=True)
df_modeC.drop(df_modeC.columns[0],axis = 1, inplace=True)
display('Mode for close:',df_modeC)
# Out:
# 'Mode for high:'
#         1       2         3         4        5         6         7         8   \
# 0  87.8654  91.396  101.4306  102.4389  102.581  102.9925  104.3513  104.6534
#
#          9         10  ...        13       14        15        16       17  \
# 0  106.9347  115.7595  ...  140.1181  147.257  153.3749  203.3777  206.979
#
#          18       19        20        21        22
# 0  218.5178  221.095  247.6846  259.5573  300.3302
#
# [1 rows x 22 columns]
# 'Mode for open:'
#           0
# 0  131.8656
# 'Mode for close:'
#         1        2         3         4         5         6         7   \
# 0  95.8986  98.5545  101.3317  101.6511  102.0094  104.5866  106.6292
#
#         8         9         10  ...        13        14        15        16  \
# 0  131.682  132.8899  133.1412  ...  134.2234  134.4167  152.6287  203.0306
#
#          17        18        19        20        21      22
# 0  214.6754  232.9946  252.1924  290.8123  296.5514  305.41
#
# ...

# %% [markdown]
# *Sasol Ltd*

# %%
df_mode =ssl[['high']].mode().transpose()
df_mode = df_mode.reset_index(drop=True)
df_mode.drop(df_mode.columns[0],axis = 1, inplace=True)
display('Mode for high:',df_mode)

df_Lmode =ssl[['low']].mode().transpose()
df_Lmode = df_Lmode.reset_index(drop=True)
df_Lmode.drop(df_Lmode.columns[0],axis = 1, inplace=True)
display('Mode for open:',df_Lmode)

df_modeC =ssl[['close']].mode().transpose()
df_modeC = df_modeC.reset_index(drop=True)
df_modeC.drop(df_modeC.columns[0],axis = 1, inplace=True)
display('Mode for close:',df_modeC)

df_modeV =ssl[['volume']].mode().transpose()
df_modeV = df_modeV.reset_index(drop=True)
df_modeV.drop(df_modeV.columns[0],axis = 1, inplace=True)
display('Mode for volume:',df_modeV)
# Out:
# 'Mode for high:'
#          1
# 0  14.3962
# 'Mode for open:'
#         1        2        3        4
# 0  13.811  15.3993  18.4085  19.8946
# 'Mode for close:'
# Empty DataFrame
# Columns: []
# Index: [0]
# 'Mode for volume:'
# Empty DataFrame
# Columns: []
# Index: [0]

# %% [markdown]
# #### *The variance for all the stock market*

# %%
variance = aapl[['open','high','low','close','volume']].var().round(2)
print('Variance for Apple Inc is :\n',variance)
# Out:
# Variance for Apple Inc is :
#  open      2.225060e+03
# high      2.281890e+03
# low       2.171610e+03
# close     2.229360e+03
# volume    3.018866e+15
# dtype: float64

# %%
variance = msft[['open','high','low','close','volume']].var().round(2)
print('Variance Microsoft for :\n',variance)
# Out:
# Variance Microsoft for :
#  open      5.663880e+03
# high      5.784380e+03
# low       5.540310e+03
# close     5.668750e+03
# volume    1.611704e+14
# dtype: float64

# %%
variance = ssl[['open','high','low','close','volume']].var().round(2)
print('Variance Sasol Ltd is :\n',variance)
# Out:
# Variance Sasol Ltd is :
#  open      7.447000e+01
# high      7.491000e+01
# low       7.389000e+01
# close     7.431000e+01
# volume    1.788704e+12
# dtype: float64

# %% [markdown]
# #### The geometric mean for all the stock market

# %% [markdown]
# *Apple Inc*

# %%
print('Geometric Mean Of Apple Inc For open:','\t',stats.gmean(aapl['open']).round(2))
print('Geometric Mean Of Apple Inc For high:','\t',stats.gmean(aapl['high']).round(2))
print('Geometric Mean Of Apple Inc For low:','\t',stats.gmean(aapl['low']).round(2))
print('Geometric Mean Of Apple Inc For close:','\t',stats.gmean(aapl['close']).round(2))
print('Geometric Mean Of Apple Inc For volume:','\t',stats.gmean(aapl['volume']).round(2))
# Out:
# Geometric Mean Of Apple Inc For open: 	 87.89
# Geometric Mean Of Apple Inc For high: 	 88.94
# Geometric Mean Of Apple Inc For low: 	 86.93
# Geometric Mean Of Apple Inc For close: 	 87.97
# Geometric Mean Of Apple Inc For volume: 	 103078497.52

# %% [markdown]
# *Microsoft Corp*

# %% [raw]
# print('Geometric Mean Of Microsoft Corp For open:','\t',stats.gmean(msft['open']).round(2))
# print('Geometric Mean Of Microsoft Corp For high:','\t',stats.gmean(msft['high']).round(2))
# print('Geometric Mean Of Microsoft Corp For low:','\t',stats.gmean(msft['low']).round(2))
# print('Geometric Mean Of Microsoft Corp For close:','\t',stats.gmean(msft['close']).round(2))
# print('Geometric Mean Of Microsoft Corp For volume:','\t',stats.gmean(msft['volume']).round(2))

# %% [markdown]
# *Sasol Ltd*

# %%
print('Geometric Mean Of Sasol Ltd For open:','\t',stats.gmean(ssl['open']).round(2))
print('Geometric Mean Of Sasol Ltd For high:','\t',stats.gmean(ssl['high']).round(2))
print('Geometric Mean Of Sasol Ltd For low:','\t',stats.gmean(ssl['low']).round(2))
print('Geometric Mean Of Sasol Ltd For close:','\t',stats.gmean(ssl['close']).round(2))
print('Geometric Mean Of Sasol Ltd For volume:','\t',stats.gmean(ssl['volume']).round(2))
# Out:
# Geometric Mean Of Sasol Ltd For open: 	 16.6
# Geometric Mean Of Sasol Ltd For high: 	 16.83
# Geometric Mean Of Sasol Ltd For low: 	 16.35
# Geometric Mean Of Sasol Ltd For close: 	 16.58
# Geometric Mean Of Sasol Ltd For volume: 	 373792.9

# %% [markdown]
# #### The kurtosis For Apple Inc for all the stock market

# %%
print( '\nopen =',round(kurtosis(aapl['open']),2) )
print( '\nhigh =', round(kurtosis(aapl['high']),2))
print( '\nlow =', round(kurtosis(aapl['low']),2))
print( '\nclose =',round(kurtosis(aapl['close']),2))
print( '\nvolume =',round(kurtosis(aapl['volume']),2))
# Out:
# open = -1.62
#
# high = -1.62
#
# low = -1.61
#
# close = -1.62
#
# volume = 5.63

# %% [markdown]
# #### The kurtosis For Microsoft Corp for all the stock market

# %%
print( '\nopen =',round(kurtosis(msft['open']),2) )
print( '\nhigh =', round(kurtosis(msft['high']),2))
print( '\nlow =', round(kurtosis(msft['low']),2))
print( '\nclose =',round(kurtosis(msft['close']),2))
print( '\nvolume =',round(kurtosis(msft['volume']),2))
# Out:
# open = -1.36
#
# high = -1.37
#
# low = -1.36
#
# close = -1.36
#
# volume = 5.79

# %% [markdown]
# #### The kurtosis For Sasol Ltd for all the stock market

# %%
from scipy.stats import kurtosis
print( '\nopen =',round(kurtosis(ssl['open']),2) )
print( '\nhigh =', round(kurtosis(ssl['high']),2))
print( '\nlow =', round(kurtosis(ssl['low']),2))
print( '\nclose =',round(kurtosis(ssl['close']),2))
print( '\nvolume =',round(kurtosis(ssl['volume']),2))
# Out:
# open = -0.8
#
# high = -0.81
#
# low = -0.79
#
# close = -0.8
#
# volume = 41.49

# %% [markdown]
# #### The standard deviation For Apple Inc for all the stock market

# %%
print('standard_deviation for Open =', round(aapl['open'].std(), 2))
print('standard_deviation for High =', round(aapl['high'].std(), 2))
print('standard_deviation for Low =', round(aapl['low'].std(), 2))
print('standard_deviation for Close =', round(aapl['close'].std(), 2))
print('standard_deviation for Volume =', round(aapl['volume'].std(), 2))
# Out:
# standard_deviation for Open = 47.17
# standard_deviation for High = 47.77
# standard_deviation for Low = 46.6
# standard_deviation for Close = 47.22
# standard_deviation for Volume = 54944205.4

# %% [markdown]
# #### The standard deviation For  Microsoft Corp for all the stock market

# %%
print('standard_deviation for Open =', round(msft['open'].std(), 2))
print('standard_deviation for High =', round(msft['high'].std(), 2))
print('standard_deviation for Low =', round(msft['low'].std(), 2))
print('standard_deviation for Close =', round(msft['close'].std(), 2))
print('standard_deviation for Volume =', round(msft['volume'].std(), 2))
# Out:
# standard_deviation for Open = 75.26
# standard_deviation for High = 76.06
# standard_deviation for Low = 74.43
# standard_deviation for Close = 75.29
# standard_deviation for Volume = 12695289.5

# %% [markdown]
# #### The standard deviation For Sasol Ltd for all the stock market

# %%
print('standard_deviation for Open =', round(ssl['open'].std(), 2))
print('standard_deviation for High =', round(ssl['high'].std(), 2))
print('standard_deviation for Low =', round(ssl['low'].std(), 2))
print('standard_deviation for Close =', round(ssl['close'].std(), 2))
# Out:
# standard_deviation for Open = 8.63
# standard_deviation for High = 8.66
# standard_deviation for Low = 8.6
# standard_deviation for Close = 8.62

# %% [markdown]
# #### The skewness For Apple Inc for all the stock market

# %% [markdown]
# *Apple Inc*

# %%
print('Skewness for Open =',round((skew(aapl['open'], axis=0, bias=True)),4))
print('Skewness for High =',round((skew(aapl['high'], axis=0, bias=True)),4))
print('Skewness for Low =',round((skew(aapl['low'], axis=0, bias=True)),4))
print('Skewness for Close =',round((skew(aapl['close'], axis=0, bias=True)),4))
print('Skewness for Volume=',round((skew(aapl['close'], axis=0, bias=True)),4))
# Out:
# Skewness for Open = 0.0284
# Skewness for High = 0.026
# Skewness for Low = 0.0323
# Skewness for Close = 0.0291
# Skewness for Volume= 0.0291

# %% [markdown]
# *Microsoft Corp*

# %%
print('Skewness for Open =',round((skew(msft['open'], axis=0, bias=True)),4))
print('Skewness for High =',round((skew(msft['high'], axis=0, bias=True)),4))
print('Skewness for Low =',round((skew(msft['low'], axis=0, bias=True)),4))
print('Skewness for Close =',round((skew(msft['close'], axis=0, bias=True)),4))
print('Skewness for Volume=',round((skew(msft['close'], axis=0, bias=True)),4))
# Out:
# Skewness for Open = 0.0461
# Skewness for High = 0.0394
# Skewness for Low = 0.0478
# Skewness for Close = 0.0439
# Skewness for Volume= 0.0439

# %% [markdown]
# *Sasol Ltd*

# %%
print('Skewness for Open =',round((skew(ssl['open'], axis=0, bias=True)),4))
print('Skewness for High =',round((skew(ssl['high'], axis=0, bias=True)),4))
print('Skewness for Low =',round((skew(ssl['low'], axis=0, bias=True)),4))
print('Skewness for Close =',round((skew(ssl['close'], axis=0, bias=True)),4))
print('Skewness for Volume=',round((skew(ssl['close'], axis=0, bias=True)),4))
# Out:
# Skewness for Open = 0.2078
# Skewness for High = 0.2112
# Skewness for Low = 0.2125
# Skewness for Close = 0.2124
# Skewness for Volume= 0.2124

# %% [markdown]
# #### The Interquartile Range For All The Stocks

# %% [markdown]
# *Apple Inc*

# %%
q3=np.quantile(aapl['open'],0.75)
q1=np.quantile(aapl['open'],0.25)
IQR=(q3-q1).round(2)
print('IQR for Open:',IQR)

q3=np.quantile(aapl['high'],0.75)
q1=np.quantile(aapl['high'],0.25)
IQR=(q3-q1).round(2)
print('IQR for high:',IQR)

q3=np.quantile(aapl['low'],0.75)
q1=np.quantile(aapl['low'],0.25)
IQR=(q3-q1).round(2)
print('IQR for low:',IQR)

q3=np.quantile(aapl['close'],0.75)
q1=np.quantile(aapl['close'],0.25)
IQR=(q3-q1).round(2)
print('IQR for close:',IQR)

q3=np.quantile(aapl['volume'],0.75)
q1=np.quantile(aapl['volume'],0.25)
IQR=(q3-q1).round(2)
print('IQR for volume:',IQR)
# Out:
# IQR for Open: 94.88
# IQR for high: 96.22
# IQR for low: 93.95
# IQR for close: 94.94
# IQR for volume: 57532330.0

# %% [markdown]
# *Microsoft Corp*

# %%
q3=np.quantile(msft['open'],0.75)
q1=np.quantile(msft['open'],0.25)
IQR=(q3-q1).round(2)
print('IQR for Open:',IQR)


q3=np.quantile(msft['high'],0.75)
q1=np.quantile(msft['high'],0.25)
IQR=(q3-q1).round(2)
print('IQR for high:',IQR)

q3=np.quantile(msft['low'],0.75)
q1=np.quantile(msft['low'],0.25)
IQR=(q3-q1).round(2)
print('IQR for low:',IQR)

q3=np.quantile(msft['close'],0.75)
q1=np.quantile(msft['close'],0.25)
IQR=(q3-q1).round(2)
print('IQR for close:',IQR)

q3=np.quantile(msft['volume'],0.75)
q1=np.quantile(msft['volume'],0.25)
IQR=(q3-q1).round(2)
print('IQR for volume:',IQR)
# Out:
# IQR for Open: 136.01
# IQR for high: 138.03
# IQR for low: 133.79
# IQR for close: 136.06
# IQR for volume: 11938480.0

# %% [markdown]
# *Sasol*

# %%
q3=np.quantile(ssl['open'],0.75)
q1=np.quantile(ssl['open'],0.25)
IQR=(q3-q1).round(2)
print('IQR for Open:',IQR)

q3=np.quantile(ssl['high'],0.75)
q1=np.quantile(ssl['high'],0.25)
IQR=(q3-q1).round(2)
print('IQR for high:',IQR)

q3=np.quantile(ssl['low'],0.75)
q1=np.quantile(ssl['low'],0.25)
IQR=(q3-q1).round(2)
print('IQR for low:',IQR)

q3=np.quantile(ssl['close'],0.75)
q1=np.quantile(ssl['close'],0.25)
IQR=(q3-q1).round(2)
print('IQR for close:',IQR)

q3=np.quantile(ssl['volume'],0.75)
q1=np.quantile(ssl['volume'],0.25)
IQR=(q3-q1).round(2)
print('IQR for volume:',IQR)
# Out:
# IQR for Open: 12.77
# IQR for high: 12.91
# IQR for low: 12.45
# IQR for close: 12.64
# IQR for volume: 335851.0

# %% [markdown]
# #### The Correlations for the Stock Markets

# %% [markdown]
# *Apple Inc*

# %%
aapl.corr()
# Out:
#             open      high       low     close    volume
# open    1.000000  0.999723  0.999667  0.999281 -0.387562
# high    0.999723  1.000000  0.999617  0.999665 -0.381294
# low     0.999667  0.999617  1.000000  0.999675 -0.395856
# close   0.999281  0.999665  0.999675  1.000000 -0.389008
# volume -0.387562 -0.381294 -0.395856 -0.389008  1.000000

# %% [markdown]
# *Microsoft Corp*

# %%
msft.corr()
# Out:
#             open      high       low     close    volume
# open    1.000000  0.999651  0.999613  0.999154 -0.071610
# high    0.999651  1.000000  0.999490  0.999581 -0.061450
# low     0.999613  0.999490  1.000000  0.999601 -0.083665
# close   0.999154  0.999581  0.999601  1.000000 -0.073805
# volume -0.071610 -0.061450 -0.083665 -0.073805  1.000000

# %% [markdown]
# *Sasol Ltd*

# %%
ssl.corr()
# Out:
#             open      high       low     close    volume
# open    1.000000  0.999777  0.999738  0.999492 -0.495830
# high    0.999777  1.000000  0.999736  0.999772 -0.489830
# low     0.999738  0.999736  1.000000  0.999806 -0.497681
# close   0.999492  0.999772  0.999806  1.000000 -0.493184
# volume -0.495830 -0.489830 -0.497681 -0.493184  1.000000

# %% [markdown]
# #### The Coefficient of Variation for all the stock markets

# %% [markdown]
# *Apple Inc*

# %%
Cols=aapl[['open','high','low','close','volume']]

print((Cols.mean()/Cols.std()).round(2))
# Out:
# open      2.12
# high      2.12
# low       2.12
# close     2.12
# volume    2.06
# dtype: float64

# %% [markdown]
# *Microsoft Corp*

# %%
Cols=msft[['open','high','low','close','volume']]

print((Cols.mean()/Cols.std()).round(2))
# Out:
# open      2.58
# high      2.58
# low       2.58
# close     2.58
# volume    2.37
# dtype: float64

# %% [markdown]
# *Sasol Ltd*

# %%
Cols=ssl[['open','high','low','close','volume']]

print((Cols.mean()/Cols.std()).round(2))
# Out:
# open      2.20
# high      2.22
# low       2.18
# close     2.20
# volume    0.53
# dtype: float64

# %% [markdown]
# #### Mean Absolute Error for all the stock markets

# %% [markdown]
# *Apple Inc*

# %%
actual = aapl['close']
predicted = aapl['open']
mae = mean_absolute_error(actual, predicted)

print('Mean Absolute Error:', mae)
# Out:
# Mean Absolute Error: 1.2212739776951669

# %% [markdown]
# *Microsoft Corp*

# %%
actual = msft['close']
predicted = msft['open']
mae = mean_absolute_error(actual, predicted)

print('Mean Absolute Error:', mae)
# Out:
# Mean Absolute Error: 2.1557020074349436

# %% [markdown]
# *Sasol Ltd*

# %%
actual = ssl['close']
predicted =ssl['open']
mae = mean_absolute_error(actual, predicted)

print('Mean Absolute Error:', mae)
# Out:
# Mean Absolute Error: 0.2089063197026022

# %% [markdown]
# #### Mean Square Error of all the stock markets

# %% [markdown]
# *Apple Inc*

# %%
actual = aapl['close']
predicted = aapl['open']
mse = mean_squared_error(actual, predicted)

print('Mean Squared Error:', mse)
# Out:
# Mean Squared Error: 3.2128530373159836

# %% [markdown]
# *Microsoft Corp*

# %%
actual = msft['close']
predicted = msft['open']
mse = mean_squared_error(actual, predicted)

print('Mean Squared Error:', mse)
# Out:
# Mean Squared Error: 9.581452814423793

# %% [markdown]
# *Sasol Ltd*

# %%
actual = ssl['close']
predicted = ssl['open']
mse = mean_squared_error(actual, predicted)

print('Mean Squared Error:', mse)
# Out:
# Mean Squared Error: 0.07636358434200745

# %% [markdown]
# #### Mean Percentage Error of all the stock markets

# %% [markdown]
# *Apple Inc*

# %%
actual = aapl['close']
predicted = aapl['open']
mape = np.mean(np.abs((actual - predicted) / actual)) * 100

print('Mean Absolute Percentage Error:', mape)
# Out:
# Mean Absolute Percentage Error: 1.1684742343884058

# %% [markdown]
# *Microsoft Corp*

# %%
actual = msft['close']
predicted = msft['open']
mape = np.mean(np.abs((actual - predicted) / actual)) * 100

print('Mean Absolute Percentage Error:', mape)
# Out:
# Mean Absolute Percentage Error: 1.0959983803212403

# %% [markdown]
# *Sasol Ltd*

# %%
actual = ssl['close']
predicted = ssl['open']
mape = np.mean(np.abs((actual - predicted) / actual)) * 100

print('Mean Absolute Percentage Error:', mape)
# Out:
# Mean Absolute Percentage Error: 1.4202188199705665

# %% [markdown]
# #### The Covariance of of all the stock Market

# %% [markdown]
# *Apple Inc*

# %%
covariance = np.cov(aapl['close'], aapl['volume'])
print('Covariance:\n', covariance)
# Out:
# Covariance:
#  [[ 2.22935508e+03 -1.00918254e+09]
#  [-1.00918254e+09  3.01886571e+15]]

# %% [markdown]
# *Sasol Ltd*

# %%
covariance = np.cov(ssl['close'], ssl['volume'])
print('Covariance:\n', covariance)
# Out:
# Covariance:
#  [[ 7.43135910e+01 -5.68607542e+06]
#  [-5.68607542e+06  1.78870385e+12]]

# %% [markdown]
# *Microsoft Corp*

# %%
covariance = np.cov(msft['close'], msft['volume'])
print('Covariance:\n', covariance)
# Out:
# Covariance:
#  [[ 5.66875039e+03 -7.05459833e+07]
#  [-7.05459833e+07  1.61170376e+14]]

# %% [markdown]
# #### The Covariance of between stock markets

# %%
covariance = aapl['volume'].pct_change().cov(ssl['volume'].pct_change())
covariance_rounded = round(covariance, 2)

print("Covariance between Apple and Sasol stock: ", covariance_rounded)
# Out:
# Covariance between Apple and Sasol stock:  0.03

# %%
covariance = msft['volume'].pct_change().cov(ssl['volume'].pct_change())
covariance_rounded = round(covariance, 2)

print("Covariance between Microsoft and Sasol: ", covariance_rounded)
# Out:
# Covariance between Microsoft and Sasol:  0.03

# %%
covariance = aapl['volume'].pct_change().cov(msft['volume'].pct_change())
covariance_rounded = round(covariance, 2)

print("Covariance between Apple and Microsoft: ", covariance_rounded)
# Out:
# Covariance between Apple and Microsoft:  0.06

# %%
covariance = aapl['volume'].pct_change().cov(ssl['volume'].pct_change())
covariance_rounded = round(covariance, 2)

print("Covariance between Apple and Sasol): ", covariance_rounded)
# Out:
# Covariance between Apple and Sasol):  0.03

# %%
covariance = msft['volume'].pct_change().cov(ssl['volume'].pct_change())
covariance_rounded = round(covariance, 2)

print("Covariance Microsoft and Sasol: ", covariance_rounded)
# Out:
# Covariance Microsoft and Sasol:  0.03

# %% [markdown]
# #### The Standard Error for all the stock market

# %% [markdown]
# *Apple Inc*

# %%
standard_deviation = aapl[['open','high','low','close','volume']].std()
total_Sum = aapl['open'].count()
standard_error = standard_deviation/np.sqrt(total_Sum)
print("standard_error:\n", standard_error)
# Out:
# standard_error:
#  open      1.286204e+00
# high      1.302525e+00
# low       1.270663e+00
# close     1.287444e+00
# volume    1.498169e+06
# dtype: float64

# %% [markdown]
# *Microsoft Corp*

# %%
standard_deviation = msft[['open','high','low','close','volume']].std()
total_Sum = msft['open'].count()
standard_error = standard_deviation/np.sqrt(total_Sum)
print("standard_error:\n", standard_error)
# Out:
# standard_error:
#  open           2.052087
# high           2.073803
# low            2.029578
# close          2.052970
# volume    346163.654259
# dtype: float64

# %% [markdown]
# *Sasol Ltd*

# %%
standard_deviation = ssl[['open','high','low','close','volume']].std()
total_Sum = ssl['open'].count()
standard_error = standard_deviation/np.sqrt(total_Sum)
print("standard_error:\n", standard_error)
# Out:
# standard_error:
#  open          0.235306
# high          0.235997
# low           0.234390
# close         0.235057
# volume    36467.675278
# dtype: float64

# %% [markdown]
# # The Statistical Graphs

# %% [markdown]
# ### Box and Whisker Plots

# %% [markdown]
# *Apple Inc*

# %%
Cols2=aapl[['open','high','low','close']]
sns.boxplot(Cols2)
plt.show()

# %%
sns.boxplot(aapl['volume'])
plt.show()

# %% [markdown]
# *Sasol Ltd*

# %%
Cols2=ssl[['open','high','low','close']]
sns.boxplot(Cols2)
plt.show()

# %%
sns.boxplot(ssl['volume'])
plt.show()

# %% [markdown]
# *Microsoft Corp*

# %%
sns.boxplot(msft['volume'])
plt.show()

# %%
Cols2=msft[['open','high','low','close']]
sns.boxplot(Cols2)
plt.show()

# %% [markdown]
# *Apple Inc*

# %%
f, axes = plt.subplots(2, 2, figsize=(15, 7), sharex=False)
sns.violinplot(aapl['open'], color="skyblue", ax=axes[0,0])
axes[0,0].set_xlabel('open')
sns.violinplot(aapl['close'], color="olive", ax=axes[0,1])
axes[0,1].set_xlabel('close')
sns.violinplot(aapl['low'], color="gold", ax=axes[1,0])
axes[1,0].set_xlabel('low')
sns.violinplot(aapl['volume'], color="skyblue", ax=axes[1,1])
axes[1,1].set_xlabel('volume')
plt.show()

# %% [markdown]
# *Microsoft Corp*

# %%
f, axes = plt.subplots(2, 2, figsize=(15, 7), sharex=False)
sns.violinplot(msft.iloc[:,0], color="skyblue", ax=axes[0,0])
axes[0,0].set_xlabel('open')
sns.violinplot(msft.iloc[:,3], color="olive", ax=axes[0,1])
axes[0,1].set_xlabel('close')
sns.violinplot(msft.iloc[:,2], color="gold", ax=axes[1,0])
axes[1,0].set_xlabel('low')
sns.violinplot(msft.iloc[:,4], color="skyblue", ax=axes[1,1])
axes[1,1].set_xlabel('volume')
plt.show()

# %% [markdown]
# *Sasol Ltd*

# %%
f, axes = plt.subplots(2, 2, figsize=(15, 7), sharex=False)
sns.violinplot(ssl.iloc[:,0], color="skyblue", ax=axes[0,0])
axes[0,0].set_xlabel('open')
sns.violinplot(ssl.iloc[:,1], color="olive", ax=axes[0,1])
axes[0,1].set_xlabel('close')
sns.violinplot(ssl.iloc[:,2], color="gold", ax=axes[1,0])
axes[1,0].set_xlabel('low')
sns.violinplot(ssl.iloc[:,4], color="skyblue", ax=axes[1,1])
axes[1,1].set_xlabel('volume')
plt.show()

# %% [markdown]
# ## Distribution Graphs

# %%
columns = ['open', 'open','open']
dfs = [aapl, msft, ssl]
fig, axs = plt.subplots(ncols=3, figsize=(12,5))
for i, col in enumerate(columns):
    skewness = dfs[i][col].skew()
    sns.histplot(dfs[i][col], ax=axs[i], kde=True)
    
plt.tight_layout()
plt.show()
print("Distribution plot showing the skewness of the data for Opening Price from AAPL, MSFT and SSL, respectively.")
# Out:
# Distribution plot showing the skewness of the data for Opening Price from AAPL, MSFT and SSL, respectively.

# %%
columns = ['high', 'high','high']
dfs = [aapl, msft, ssl]
fig, axs = plt.subplots(ncols=3, figsize=(12,5))

for i, col in enumerate(columns):
    skewness = dfs[i][col].skew()
    sns.histplot(dfs[i][col], ax=axs[i], kde=True)
    
plt.tight_layout()
plt.show()
print("Distribution plot showing the skewness of the data for Highest Price from AAPL, MSFT and SSL, respectively.")
# Out:
# Distribution plot showing the skewness of the data for Highest Price from AAPL, MSFT and SSL, respectively.

# %%
columns = ['close', 'close','close']
dfs = [aapl, msft, ssl]
fig, axs = plt.subplots(ncols=3, figsize=(12,5))

for i, col in enumerate(columns):
    skewness = dfs[i][col].skew()
    sns.histplot(dfs[i][col], ax=axs[i], kde=True)
    
plt.tight_layout()
plt.show()
print("Distribution plot showing the skewness of the data for Closing Price from AAPL, MSFT and SSL, respectively.")
# Out:
# Distribution plot showing the skewness of the data for Closing Price from AAPL, MSFT and SSL, respectively.

# %%
columns = ['low', 'low','low']
dfs = [aapl, msft, ssl]
fig, axs = plt.subplots(ncols=3, figsize=(12,5))

for i, col in enumerate(columns):
    skewness = dfs[i][col].skew()
    sns.histplot(dfs[i][col], ax=axs[i], kde=True)
    
plt.tight_layout()
plt.show()
print("Distribution plot showing the skewness of the data for Lowest Price from AAPL, MSFT and SSL, respectively.")
# Out:
# Distribution plot showing the skewness of the data for Lowest Price from AAPL, MSFT and SSL, respectively.

# %%
columns = ['volume', 'volume','volume']
dfs = [aapl, msft, ssl]
fig, axs = plt.subplots(ncols=3, figsize=(12,5))

for i, col in enumerate(columns):
    skewness = dfs[i][col].skew()
    sns.histplot(dfs[i][col], ax=axs[i], kde=True)

plt.tight_layout()
plt.show()
print("Distribution plot showing the skewness of the data for Volume from AAPL, MSFT and SSL, respectively.")
# Out:
# Distribution plot showing the skewness of the data for Volume from AAPL, MSFT and SSL, respectively.

# %% [markdown]
# ### The Linear Regression Graphs for all stock markets

# %% [markdown]
# *Apple Inc*

# %%
X = pd.DataFrame(aapl['open'])
y = pd.DataFrame(aapl['close'])

model = LinearRegression()
model.fit(X, y)
print('Regression Coefficients:', model.coef_.round(3))
print('Intercept:', model.intercept_.round(2))
print('R-squared:', model.score(X, y).round(2))
plt.scatter(X, y, color='blue')
plt.plot(X, model.predict(X), color='red', linewidth=2)
plt.title('Linear Regression For AAPL stock Market Data')
plt.xlabel('Opening Price')
plt.ylabel('Closing Price')
plt.show()
# Out:
# Regression Coefficients: [[1.]]
# Intercept: [0.07]
# R-squared: 1.0

# %% [markdown]
# *Microsoft Corp*

# %%
X = pd.DataFrame(msft['open'])
y = pd.DataFrame(msft['close'])

model = LinearRegression()
model.fit(X, y)
print('Regression Coefficients:', model.coef_.round(3))
print('Intercept:', model.intercept_.round(2))
print('R-squared:', model.score(X, y).round(2))

plt.scatter(X, y, color='blue')
plt.plot(X, model.predict(X), color='red', linewidth=2)
plt.title('Linear Regression For MSFT stock Market Data')
plt.xlabel('Opening Price')
plt.ylabel('Closing Price')
plt.show()
# Out:
# Regression Coefficients: [[1.]]
# Intercept: [0.14]
# R-squared: 1.0

# %% [markdown]
# *Sasol Ltd*

# %%
X = pd.DataFrame(ssl['open'])
y = pd.DataFrame(ssl['close'])

model = LinearRegression()
model.fit(X, y)
print('Regression Coefficients:', model.coef_.round(3))
print('Intercept:', model.intercept_.round(2))
print('R-squared:', model.score(X, y).round(2))

plt.scatter(X, y, color='blue')
plt.plot(X, model.predict(X), color='red', linewidth=2)
plt.title('Linear Regression For SSL stock Market Data')
plt.xlabel('Opening Price')
plt.ylabel('Closing Price')
plt.show()
# Out:
# Regression Coefficients: [[0.998]]
# Intercept: [0.]
# R-squared: 1.0

# %% [markdown]
# ### The Correlation Graphs

# %% [markdown]
# *Apple Inc*

# %%
plt.scatter(aapl['close'],aapl['volume'])
plt.xlabel('Closing Price')
plt.ylabel('Volume')
plt.title("Scatter Plot For APPLE(Close vs.Volume)")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# *Microsoft Corp*

# %%
plt.scatter(msft['close'],aapl['volume'])
plt.xlabel('Closing Price')
plt.ylabel('Volume')
plt.title("Scatter Plot For Microsoft(Close vs.Volume)")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# *Sasol Ltd*

# %%
plt.scatter(ssl['close'],aapl['volume'])
plt.xlabel('Closing Price')
plt.ylabel('Volume')
plt.title("Scatter Plot For Sasol(Close vs.Volume)")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Market Summary Graphs For Include The Stock Market

# %%
aapl2 = pd.read_excel(r'/home/f5384478/Documents/personal/Assigment 4/MacroTrends_Data_Apple.xlsx')
print(aapl2)
# Out:
#            date      open      high       low     close     volume
# 0    2018-01-02   40.3879   40.8958   40.1743   40.8863  102223736
# 1    2018-01-03   40.9504   41.4299   40.8151   40.8792  118071596
# 2    2018-01-04   40.9528   41.1735   40.8436   41.0691   89738388
# 3    2018-01-05   41.1664   41.6245   41.0738   41.5367   94640072
# 4    2018-01-08   41.3824   41.6815   41.2827   41.3824   82271064
# ...         ...       ...       ...       ...       ...        ...
# 1340 2023-05-01  169.2800  170.4500  168.6400  169.5900   49391604
# 1341 2023-05-02  170.0900  170.3500  167.5400  168.5400   47986184
# 1342 2023-05-03  169.5000  170.9200  167.1600  167.4500   59438769
# 1343 2023-05-04  164.8900  167.0400  164.3100  165.7900   70216187
# 1344 2023-05-05  170.9750  174.3000  170.7600  173.5700  110756599
#
# [1345 rows x 6 columns]

# %%
msft2 = pd.read_excel(r'/home/f5384478/Documents/personal/Assigment 4/MacroTrends_Data_Microsoft.xlsx')
print(msft2)
# Out:
#            date      open      high       low     close    volume
# 0    2018-01-02   81.1606   81.3349   80.5716   80.9957  22483797
# 1    2018-01-03   81.0946   81.5234   81.0145   81.3726  26061439
# 2    2018-01-04   81.5988   82.6071   81.5799   82.0888  21911974
# 3    2018-01-05   82.6071   83.3139   82.3903   83.1065  23407110
# 4    2018-01-08   83.1160   83.4741   82.5549   83.1913  22113049
# ...         ...       ...       ...       ...       ...       ...
# 1340 2023-05-01  306.9700  308.6000  305.1500  305.5600  21252788
# 1341 2023-05-02  307.7600  309.1800  303.9100  305.4100  26320444
# 1342 2023-05-03  306.6200  308.6100  304.0900  304.4000  22157529
# 1343 2023-05-04  306.2400  307.7626  303.4000  305.4100  22198119
# 1344 2023-05-05  305.7200  311.9700  304.2700  310.6500  27360645
#
# [1345 rows x 6 columns]

# %%
ssl2 = pd.read_excel(r'/home/f5384478/Documents/personal/Assigment 4/MacroTrends_Data_Sasol.xlsx')
print(ssl2)
# Out:
#            date     open     high      low    close  volume
# 0    2018-01-02  30.4805  30.6007  30.3734  30.5698  225415
# 1    2018-01-03  30.5341  30.8376  30.4894  30.7841  169394
# 2    2018-01-04  30.4270  30.8823  30.4270  30.8019  126648
# 3    2018-01-05  30.9448  31.0698  30.8109  30.9805  173940
# 4    2018-01-08  31.0341  31.2216  30.9805  31.0519  149534
# ...         ...      ...      ...      ...      ...     ...
# 1340 2023-05-01  13.0100  13.0700  12.8800  12.9400  111966
# 1341 2023-05-02  12.6600  12.6600  12.2900  12.4700  290968
# 1342 2023-05-03  12.4200  12.5000  12.2800  12.2800  295698
# 1343 2023-05-04  12.2400  12.3500  12.0300  12.0400  270116
# 1344 2023-05-05  12.4100  12.6800  12.4100  12.6300  270684
#
# [1345 rows x 6 columns]

# %%
plt.plot(aapl2['date'], aapl2['close'], label='APPL')
plt.plot(ssl2['date'], ssl2['close'], label='SSL')
plt.plot(msft2['date'], msft2['close'], label='MSFT')

plt.xlabel('Year')
plt.ylabel('Closing Price(R)')
plt.title('Closing price for Three stock markets')
plt.legend()
plt.show()

# %%
plt.plot(aapl2['date'], aapl2['volume'], label='APPL')
plt.plot(ssl2['date'], ssl2['volume'], label='SSL')
plt.plot(msft2['date'], msft2['volume'], label='MSFT')

plt.xlabel('Year')
plt.ylabel('Volume')
plt.title('Volume for Three stock markets')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(16,5))
ax.plot(aapl2['date'], aapl2['open'], label='aapl open')
ax.plot(ssl2['date'], ssl2['open'], label='ssl open')
ax.plot(msft2['date'], msft2['open'], label='msft open')
ax.legend()
ax.set_title("Opening Price For All Stock")
ax.set_xlabel('Year')
ax.set_ylabel('Stock Prices')
plt.show()

# %%
aapl2['SMA_100'] = sma_indicator(aapl2['close'], 400)
plt.plot(aapl2['date'], aapl2['close'], label='AAPL Close Price')
plt.plot(aapl2['date'], aapl2['SMA_100'], label='SMA 100')
plt.legend()
plt.xlabel('Year')
plt.ylabel('Stock Prices')
plt.show()

# %%
msft2['SMA_100'] = sma_indicator(msft2['close'], 400)
plt.plot(aapl2['date'], msft2['close'], label='MSFT Close Price')
plt.plot(msft2['date'], msft2['SMA_100'], label='SMA 100')
plt.legend()
plt.xlabel('Year')
plt.ylabel('Stock Prices')
plt.show()

# %%
ssl2['SMA_100'] = sma_indicator(ssl2['close'], 400)
plt.plot(ssl2['date'], ssl2['close'], label='SSL Close Price')
plt.plot(ssl2['date'], ssl2['SMA_100'], label='SMA 100')
plt.legend()
plt.xlabel('Year')
plt.ylabel('Stock Prices')
plt.show()

# %%
aapl2['RSI'] = ta.momentum.RSIIndicator(aapl2['close']).rsi()

fig, axs = plt.subplots(2, 1, gridspec_kw={"height_ratios": [3,1]}, figsize=(10,6))
axs[0].plot(aapl2['date'], aapl2['close'])
axs[1].axhline(y=70, color="r", linestyle="--")
axs[1].axhline(y=30, color="g", linestyle="--")
axs[1].plot(aapl2['date'], aapl2['RSI'],color="orange")

# %%
msft2['RSI'] = ta.momentum.RSIIndicator(msft2['close']).rsi()

fig, axs = plt.subplots(2, 1, gridspec_kw={"height_ratios": [3,1]}, figsize=(10,6))
axs[0].plot(msft2['date'], msft2['close'])
axs[1].axhline(y=70, color="r", linestyle="--")
axs[1].axhline(y=30, color="g", linestyle="--")

axs[1].plot(msft2['date'], msft2['RSI'],color="orange")

# %%
ssl2['RSI'] = ta.momentum.RSIIndicator(ssl2['close']).rsi()

fig, axs = plt.subplots(2, 1, gridspec_kw={"height_ratios": [3,1]}, figsize=(10,6))
axs[0].plot(ssl2['date'], ssl2['close'])
axs[1].axhline(y=70, color="r", linestyle="--")
axs[1].axhline(y=30, color="g", linestyle="--")
axs[1].plot(ssl2['date'], ssl2['RSI'],color="orange")

# %%
macd = ta.trend.MACD(aapl2['close']).macd()

signal = ta.trend.MACD(aapl2['close']).macd_signal()
hist = ta.trend.MACD(aapl2['close']).macd_diff()
fig, axs = plt.subplots(nrows=2, sharex=True, figsize=(12, 8))
fig.suptitle('MACD for Apple Stock Market')
axs[0].plot(aapl2.index, aapl2['close'], label='Price')
axs[0].legend()
axs[1].plot(aapl2.index, macd, label='MACD', color='blue')
axs[1].plot(aapl2.index, signal, label='Signal', color='red')
axs[1].bar(aapl2.index, hist, label='Histogram', color='grey')

axs[1].legend()
axs[1].set_xlabel('Date')
axs[1].set_ylabel('MACD')
fig.autofmt_xdate(rotation=45)

plt.show()

# %%
macd = ta.trend.MACD(msft2['close']).macd()

signal = ta.trend.MACD(msft2['close']).macd_signal()
hist = ta.trend.MACD(msft2['close']).macd_diff()
fig, axs = plt.subplots(nrows=2, sharex=True, figsize=(12, 8))
fig.suptitle('MACD for Microsoft Stock Market')
axs[0].plot(msft2.index, msft2['close'], label='Price')
axs[0].legend()
axs[1].plot(msft2.index, macd, label='MACD', color='blue')
axs[1].plot(msft2.index, signal, label='Signal', color='red')
axs[1].bar(msft2.index, hist, label='Histogram', color='grey')

axs[1].legend()
axs[1].set_xlabel('Date')
axs[1].set_ylabel('MACD')
fig.autofmt_xdate(rotation=45)

plt.show()

# %%
macd = ta.trend.MACD(ssl2['close']).macd()

signal = ta.trend.MACD(ssl2['close']).macd_signal()
hist = ta.trend.MACD(ssl2['close']).macd_diff()
fig, axs = plt.subplots(nrows=2, sharex=True, figsize=(12, 8))
fig.suptitle('MACD for Sasol Stock Market')
axs[0].plot(ssl2.index, ssl2['close'], label='Price')
axs[0].legend()
axs[1].plot(ssl2.index, macd, label='MACD', color='blue')
axs[1].plot(ssl2.index, signal, label='Signal', color='red')
axs[1].bar(ssl2.index, hist, label='Histogram', color='grey')

axs[1].legend()
axs[1].set_xlabel('Date')
axs[1].set_ylabel('MACD')
fig.autofmt_xdate(rotation=45)

plt.show()
